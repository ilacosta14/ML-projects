# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb

# %% [markdown]
# ## Importing the dataset

# %%
train_dataset = pd.read_csv('train.csv') #import the dataset, read_csv is a function that reads the csv file
test_dataset = pd.read_csv('test.csv') 

print("Full train dataset shape is {}".format(train_dataset.shape))
print("Full test dataset shape is {}".format(test_dataset.shape))
train_dataset.describe()
# Out:
# Full train dataset shape is (1460, 81)
# Full test dataset shape is (1459, 80)
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# ...

# %%
test_dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
plt.scatter(x='LotFrontage', y='SalePrice', data=train_dataset)

# %%
train_dataset.query('LotArea > 55000')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1396  1397          20       RL          NaN    57200   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 249          Low    AllPub  ...        0    NaN   NaN        Shed     500
# 313          Low    AllPub  ...        0    NaN   NaN         NaN       0
# 335          HLS    AllPub  ...        0    NaN   NaN        Shed     700
# ...

# %% [markdown]
# ## Taking care of missing data

# %%
# dataset.info()
missing_percentage = (train_dataset.isnull().sum() / len(train_dataset)) * 100 # Calculate the percentage of missing values for each column
filtered_missing_percentage = missing_percentage[missing_percentage > 0]
print(filtered_missing_percentage)
# Out:
# LotFrontage     17.739726
# Alley           93.767123
# MasVnrType      59.726027
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# FireplaceQu     47.260274
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# PoolQC          99.520548
# Fence           80.753425
# MiscFeature     96.301370
# dtype: float64

# %%
train_dataset['Alley'].unique()
train_dataset['Fence'].unique()
# Out:
# array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
train_dataset['Alley'].fillna('No', inplace=True) # Fill missing values in 'Alley' with 'No'
train_dataset['Fence'].fillna('No', inplace=True) 
test_dataset['Alley'].fillna('No', inplace=True)
test_dataset['Fence'].fillna('No', inplace=True)
# Out:
# /tmp/ipykernel_86877/1063837691.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_dataset['Alley'].fillna('No', inplace=True) # Fill missing values in 'Alley' with 'No'
# /tmp/ipykernel_86877/1063837691.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Some of the data columns have more than 45% missing data. I will get rid of them

# %%
train_dataset.set_index('Id', inplace=True) # Set 'Id' as the index of the DataFram
train_dataset=train_dataset.drop([ 'MasVnrType', 'FireplaceQu', 'PoolQC','MiscFeature'], axis='columns')
train_dataset.head(3)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave    No      Reg
# 2           20       RL         80.0     9600   Pave    No      Reg
# 3           60       RL         68.0    11250   Pave    No      IR1
#
#    LandContour Utilities LotConfig  ... 3SsnPorch ScreenPorch PoolArea Fence  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...         0           0        0    No
# 2          Lvl    AllPub       FR2  ...         0           0        0    No
# 3          Lvl    AllPub    Inside  ...         0           0        0    No
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1        0      2    2008        WD         Normal     208500
# 2        0      5    2007        WD         Normal     181500
# 3        0      9    2008        WD         Normal     223500
#
# [3 rows x 76 columns]

# %%
test_dataset=test_dataset.drop([ 'MasVnrType', 'FireplaceQu', 'PoolQC','MiscFeature'], axis='columns')

# %% [markdown]
# Substitute missing values in float columns with average

# %%
from sklearn.impute import SimpleImputer
# Seleziona solo le colonne numeriche
numeric_cols = train_dataset.select_dtypes(include=[np.number]).columns
numeric_cols_2 = test_dataset.select_dtypes(include=[np.number]).columns

# Crea e applica l'imputer solo alle colonne numeriche sia al train che al test dataset
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
train_dataset[numeric_cols] = imputer.fit_transform(train_dataset[numeric_cols])
test_dataset[numeric_cols_2] = imputer.fit_transform(test_dataset[numeric_cols_2])

# %% [markdown]
# checking for additional nan

# %%
missing_percentage = (train_dataset.isnull().sum() / len(train_dataset)) * 100 # Calculate the percentage of missing values for each column
filtered_missing_percentage = missing_percentage[missing_percentage > 0]
print(filtered_missing_percentage)
# Out:
# BsmtQual        2.534247
# BsmtCond        2.534247
# BsmtExposure    2.602740
# BsmtFinType1    2.534247
# BsmtFinType2    2.602740
# Electrical      0.068493
# GarageType      5.547945
# GarageFinish    5.547945
# GarageQual      5.547945
# GarageCond      5.547945
# dtype: float64

# %%
train_dataset['GarageQual'].fillna('No', inplace=True) 
train_dataset['GarageCond'].fillna('No', inplace=True)
train_dataset['GarageFinish'].fillna('No', inplace=True)
train_dataset['GarageType'].fillna('No', inplace=True)
train_dataset['BsmtQual'].fillna('Unf', inplace=True)
train_dataset['BsmtCond'].fillna('Unf', inplace=True)
train_dataset['BsmtFinType1'].fillna('Unf', inplace=True)
# Out:
# /tmp/ipykernel_86877/1314574414.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_dataset['GarageQual'].fillna('No', inplace=True)
# /tmp/ipykernel_86877/1314574414.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
test_dataset['GarageQual'].fillna('No', inplace=True) 
test_dataset['GarageCond'].fillna('No', inplace=True)
test_dataset['GarageFinish'].fillna('No', inplace=True)
test_dataset['GarageType'].fillna('No', inplace=True)
test_dataset['BsmtQual'].fillna('Unf', inplace=True)
test_dataset['BsmtCond'].fillna('Unf', inplace=True)
test_dataset['BsmtFinType1'].fillna('Unf', inplace=True)
# Out:
# /tmp/ipykernel_86877/1412600231.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_dataset['GarageQual'].fillna('No', inplace=True)
# /tmp/ipykernel_86877/1412600231.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
train_dataset = train_dataset.dropna() # Drop rows with any remaining missing values
train_dataset.shape
# Out:
# (1420, 76)

# %% [markdown]
# Graphical representation to check null value

# %%
sb.heatmap(train_dataset.isnull())
print("Full train dataset shape is now {}".format(train_dataset.shape))
# Out:
# Full train dataset shape is now (1420, 76)

# %% [markdown]
# ## Check distribution of Sales

# %%
print(train_dataset['SalePrice'].describe())
plt.figure(figsize=(9, 8))
sb.histplot(train_dataset['SalePrice'], color='g', bins=100, alpha=0.4)
# Out:
# count      1420.000000
# mean     182811.119014
# std       79424.562170
# min       34900.000000
# 25%      131500.000000
# 50%      165000.000000
# 75%      215000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
train_dataset['SalePrice'] = np.log1p(train_dataset['SalePrice'])

# %%
data_num = train_dataset.select_dtypes(include = ['float64', 'int64'])
data_num.head()
data_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<Axes: title={'center': 'MSSubClass'}>,
#         <Axes: title={'center': 'LotFrontage'}>,
#         <Axes: title={'center': 'LotArea'}>,
#         <Axes: title={'center': 'OverallQual'}>,
#         <Axes: title={'center': 'OverallCond'}>,
#         <Axes: title={'center': 'YearBuilt'}>],
#        [<Axes: title={'center': 'YearRemodAdd'}>,
#         <Axes: title={'center': 'MasVnrArea'}>,
#         <Axes: title={'center': 'BsmtFinSF1'}>,
#         <Axes: title={'center': 'BsmtFinSF2'}>,
#         <Axes: title={'center': 'BsmtUnfSF'}>,
#         <Axes: title={'center': 'TotalBsmtSF'}>],
#        [<Axes: title={'center': '1stFlrSF'}>,
#         <Axes: title={'center': '2ndFlrSF'}>,
#         <Axes: title={'center': 'LowQualFinSF'}>,
#         <Axes: title={'center': 'GrLivArea'}>,
#         <Axes: title={'center': 'BsmtFullBath'}>,
#         <Axes: title={'center': 'BsmtHalfBath'}>],
#        [<Axes: title={'center': 'FullBath'}>,
# ...

# %% [markdown]
# ## Encoding the Categorical data

# %%
# from sklearn.preprocessing import OneHotEncoder

# categorical_cols = dataset.select_dtypes(include=['object', 'category']).columns
# encoder = OneHotEncoder(sparse_output=False, drop=None)
# encoded = encoder.fit_transform(dataset[categorical_cols])

# # Crea un DataFrame con i nuovi nomi delle colonne
# encoded_dataset = pd.DataFrame(encoded, columns=encoder.get_feature_names_out(categorical_cols), index=dataset.index)

# # Unisci le colonne numeriche e quelle codificate
# dataset = pd.concat([dataset.drop(columns=categorical_cols), encoded_dataset], axis=1)
# dataset.head(3)

# %%
train_dataset.dtypes[train_dataset.dtypes == 'object']
# Out:
# MSZoning         object
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# Fence            object
# SaleType         object
# ...

# %% [markdown]
# We want to separate the object data in ordered and unordered data

# %%
ode_cols = ['LotShape', 'LandContour','Utilities','LandSlope',  'BsmtQual',  'BsmtFinType1', 'BsmtFinType2' , 'CentralAir',  'Functional', 'GarageFinish', 'GarageQual', 'PavedDrive', 'ExterCond', 'KitchenQual', 'BsmtExposure', 'HeatingQC','ExterQual', 'BsmtCond', 'GarageCond','Fence'] #data we will handle with ordinal encoding
ohe_cols = ['Street','Alley','LotConfig','Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st', 'Exterior2nd','Foundation',  'Electrical',  'SaleType', 'SaleCondition', 'Heating', 'GarageType', 'RoofMatl', 'MSZoning'] #data we will handle with one-hot encoding

# %% [markdown]
# #### Build Pipeline to transofrm categorical data

# %%
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

ode_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('ode', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])
ohe_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
col_trans = ColumnTransformer(transformers=[
    ('ode_p', ode_pipeline, ode_cols),
    ('ohe_p', ohe_pipeline, ohe_cols),
    ],
    remainder='passthrough', 
    n_jobs=-1)

# %%
pipeline = Pipeline(steps=[
    ('preprocessing', col_trans)
])

# %% [markdown]
# ## Define variables x and y

# %%
X = train_dataset.drop('SalePrice',axis=1) #define x, putting all the rows and all the columns except the last one
y = train_dataset['SalePrice'] #define y, putting all the rows but only the last column

X_p = pipeline.fit_transform(X) #X preprocessed
print(X_p)
# Out:
# [[3.000e+00 3.000e+00 0.000e+00 ... 0.000e+00 2.000e+00 2.008e+03]
#  [3.000e+00 3.000e+00 0.000e+00 ... 0.000e+00 5.000e+00 2.007e+03]
#  [0.000e+00 3.000e+00 0.000e+00 ... 0.000e+00 9.000e+00 2.008e+03]
#  ...
#  [3.000e+00 3.000e+00 0.000e+00 ... 2.500e+03 5.000e+00 2.010e+03]
#  [3.000e+00 3.000e+00 0.000e+00 ... 0.000e+00 4.000e+00 2.010e+03]
#  [3.000e+00 3.000e+00 0.000e+00 ... 0.000e+00 6.000e+00 2.008e+03]]

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_p,y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ## Training the Random Forest Regression model on the whole dataset

# %%
param_grid = { 'max_depth': [5, 10, 15], 'n_estimators': [100, 250, 500], 'min_samples_split': [3, 5, 10] }

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(random_state = 42) # Create a Random Forest Regressor

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score
regressor_cv = GridSearchCV(regressor, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
regressor_cv.fit(X_train, y_train)
np.sqrt(-1 * regressor_cv.best_score_)
# Out:
# 0.15062383412745112

# %% [markdown]
# ## Apply model on the test dataset

# %%
test_dataset
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461.0        20.0       RH         80.0  11622.0   Pave    No      Reg
# 1     1462.0        20.0       RL         81.0  14267.0   Pave    No      IR1
# 2     1463.0        60.0       RL         74.0  13830.0   Pave    No      IR1
# 3     1464.0        60.0       RL         78.0   9978.0   Pave    No      IR1
# 4     1465.0       120.0       RL         43.0   5005.0   Pave    No      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915.0       160.0       RM         21.0   1936.0   Pave    No      Reg
# 1455  2916.0       160.0       RM         21.0   1894.0   Pave    No      Reg
# 1456  2917.0        20.0       RL        160.0  20000.0   Pave    No      Reg
# 1457  2918.0        85.0       RL         62.0  10441.0   Pave    No      Reg
# 1458  2919.0        60.0       RL         74.0   9627.0   Pave    No      Reg
#
# ...

# %%
data_test_preprocess = pipeline.transform(test_dataset)
estimator = regressor_cv.best_estimator_
y_stacking = np.exp(estimator.predict(data_test_preprocess))

df_y_stacking_out = test_dataset[['Id']]
df_y_stacking_out['Id'] = df_y_stacking_out['Id'].astype(int)
df_y_stacking_out['SalePrice'] = y_stacking

df_y_stacking_out.to_csv('submission.csv', index=False)
# Out:
# /tmp/ipykernel_86877/1963371538.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y_stacking_out['Id'] = df_y_stacking_out['Id'].astype(int)
# /tmp/ipykernel_86877/1963371538.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y_stacking_out['SalePrice'] = y_stacking
